# %% [markdown]
# <b>1. What does an empty dictionary&#39;s code look like?

# %% [markdown]
# {}

# %% [markdown]
# <b>2. What is the value of a dictionary value with the key &#39;foo&#39; and the value 42?

# %% [markdown]
# 42

# %% [markdown]
# <b>3. What is the most significant distinction between a dictionary and a list?

# %% [markdown]
# A list holds just values. While dictionary holds items in the form of key-value pair. <br>
# Values in list are accessed using index. While dictionary values are accessed using keys

# %% [markdown]
# <b>4. What happens if you try to access spam[&#39;foo&#39;] if spam is {&#39;bar&#39;: 100}?

# %% [markdown]
# We get a KeyError. We need to use .get() to prevent an error. .get() in this case returns nothing

# %% [markdown]
# <b>5. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.keys()?

# %% [markdown]
# Both return the same result

# %% [markdown]
# <b>6. If a dictionary is stored in spam, what is the difference between the expressions &#39;cat&#39; in spam and
# &#39;cat&#39; in spam.values()?

# %% [markdown]
# 'cat' in spam searches in keys of dictionary. While, 'cat' in spam.values() searches in values of dictionary

# %% [markdown]
# <b>7. What is a shortcut for the following code?
# if &#39;color&#39; not in spam:
# spam[&#39;color&#39;] = &#39;black&#39;

# %% [markdown]
# spam['color'] = 'black' is enough. If a key is not found in dictionary during value assignment to a key. Python creates a key and assigns value.

# %% [markdown]
# <b>8. How do you &quot;pretty print&quot; dictionary values using which module and function?

# %% [markdown]
# using pprint module's pprint function
